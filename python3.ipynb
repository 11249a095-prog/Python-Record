# %% [markdown]
# <a href="https://colab.research.google.com/github/11249a095-prog/Python-Record/blob/main/python3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 3.Fibonacci sequence: Defined as a function F as Fn=Fn-1+Fn-2.Write a python program which accepts a value for N (Where N>0) as input and pass this value to the function.Display suitable error message if the condition for input value is not followed.

# %%
number = input("Enter a number: ")
if number == number[::-1]:
 print("Palindrome")
else:
 print("Not Palindrome")
for i in range(10):
 count = number.count(str(i))
if count > 0:
 print(f"{i} appears {count} times")
# Out:
# Enter a number: 9
# Palindrome
# 9 appears 1 times
